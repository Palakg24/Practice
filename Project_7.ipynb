# %% [markdown]
# <a href="https://colab.research.google.com/github/Palakg24/Practice/blob/main/Project_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-24dd19c2-c132-482f-a32e-3aa9ddd96235" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-24dd19c2-c132-482f-a32e-3aa9ddd96235">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
data=pd.read_csv('Udemy Courses Dataset.csv')

# %%
data
# Out:
#       course_id                                       course_title  is_paid  \
# 0        288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1       1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2       1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3       1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4       1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
# ...         ...                                                ...      ...
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
# ...

# %%
data.head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments
# 1           1 hour  2017-04-12T19:06:34Z  Musical Instruments

# %%
data.subject.unique()
# Out:
# array(['Musical Instruments', 'Business Finance', 'Graphic Design',
#        'Web Development'], dtype=object)

# %%
data.subject.value_counts()
# Out:
# subject
# Web Development        1200
# Business Finance       1199
# Musical Instruments     680
# Graphic Design          603
# Name: count, dtype: int64

# %%
data.head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments
# 1           1 hour  2017-04-12T19:06:34Z  Musical Instruments

# %%
data[data.is_paid == False][['subject','course_title','is_paid']]
# Out:
#                   subject                                       course_title  \
# 41    Musical Instruments        5 lecciones que todo guitarrista debe tomar
# 49    Musical Instruments  7 Ways A Beginner Guitarist Can Sound Better, ...
# 57    Musical Instruments  A beginner`s guide to fingerpicking and strumm...
# 67        Web Development                             A how to guide in HTML
# 74       Business Finance  ¡Triunfar en La Bolsa de Valores No Requiere d...
# ...                   ...                                                ...
# 3620      Web Development  WordPress in under an hour - Create/manage you...
# 3638      Web Development                     Wordpress Website Mastery 2017
# 3652      Web Development  Write quicker HTML5 and CSS 3; productivity ha...
# 3674  Musical Instruments  Your First 10 Guitar Lessons - Learn how to pl...
# 3680     Business Finance  Zoho Books Gestion Financière d'Entreprise pas...
#
#       is_paid
# 41      False
# ...

# %%
data[data.is_paid == True][['course_title','is_paid']]
# Out:
#                                            course_title  is_paid
# 0     #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1     #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2     #12 Hand Coordination: Let your Hands dance wi...     True
# 3     #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4     #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
# ...                                                 ...      ...
# 3676  Your First Successful Forex Trades - With Case...     True
# 3677  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678    Your Second Course on Piano: Two Handed Playing     True
# 3679  Zend Framework 2: Learn the PHP framework ZF2 ...     True
# 3681                Zombie Apocalypse Photoshop Actions     True
#
# [3372 rows x 2 columns]

# %%
data.head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments
# 1           1 hour  2017-04-12T19:06:34Z  Musical Instruments

# %%
data.sort_values('num_subscribers', ascending=False)[['course_title','num_subscribers']]
# Out:
#                                            course_title  num_subscribers
# 2230               Learn HTML5 Programming From Scratch           268923
# 776                      Coding for Entrepreneurs Basic           161029
# 3385                         The Web Developer Bootcamp           121584
# 640   Build Your First Website in 1 Week with HTML5 ...           120291
# 3316              The Complete Web Developer Course 2.0           114512
# ...                                                 ...              ...
# 2290  Learn Pirates of the Caribbean by Ear on the P...                0
# 1267                Financial Statement Auditing Cycles                0
# 2070                Kickstarter success in 5 easy steps                0
# 1931  Introduction to Project Management for Finance...                0
# 3165  Stop Creditors from Harassing you and Avoid Ba...                0
#
# [3682 rows x 2 columns]

# %%
data.sort_values('num_subscribers')[['course_title','num_subscribers']]
# Out:
#                                            course_title  num_subscribers
# 649                       Building a Balanced Scorecard                0
# 3259          The Cash Flow Statement - An Introduction                0
# 3261                    The Complete Adobe Spark Course                0
# 910        Create Beautiful Image Maps for Your Website                0
# 3328        The Cuckoo Strategy to get European Funding                0
# ...                                                 ...              ...
# 3316              The Complete Web Developer Course 2.0           114512
# 640   Build Your First Website in 1 Week with HTML5 ...           120291
# 3385                         The Web Developer Bootcamp           121584
# 776                      Coding for Entrepreneurs Basic           161029
# 2230               Learn HTML5 Programming From Scratch           268923
#
# [3682 rows x 2 columns]

# %%
data.head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments
# 1           1 hour  2017-04-12T19:06:34Z  Musical Instruments

# %%
data.price.dtype
# Out:
# dtype('O')

# %%
data.price = pd.to_numeric(data.price , errors='coerce')

# %%
data[(data.subject=='Graphic Design') & (data.price<100)][['subject', 'course_title','price']]
# Out:
#              subject                                       course_title  price
# 8     Graphic Design  :::Beginners Guide To Creating Amazing Images ...   25.0
# 20    Graphic Design  15  Motion Graphic Elements in After Effect (S...   30.0
# 35    Graphic Design  3DS MAX - Learn 3Ds MAX tutorial for Beginners...   20.0
# 39    Graphic Design                     48 Logo Designs and Techniques   20.0
# 52    Graphic Design       8 Stunden professionelles Cinema 4D Training   50.0
# ...              ...                                                ...    ...
# 3568  Graphic Design                 Web Elements Design With Photoshop   45.0
# 3588  Graphic Design  Whiteboard Animation, Beginner To Expert - In ...   20.0
# 3639  Graphic Design         Wordpress: Comment utiliser le thème FABLE   20.0
# 3671  Graphic Design  YOU can Draw, Shade and Paint a Mixed Media Gi...   30.0
# 3681  Graphic Design                Zombie Apocalypse Photoshop Actions   50.0
#
# [450 rows x 3 columns]

# %%
data.subject.unique()
# Out:
# array(['Musical Instruments', 'Business Finance', 'Graphic Design',
#        'Web Development'], dtype=object)

# %%
data[data.course_title.str.contains('Python')][['course_title']].count()
# Out:
# course_title    29
# dtype: int64

# %%
data.head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
#
#    price  num_subscribers  num_reviews  num_lectures               level  \
# 0   35.0             3137           18            68          All Levels
# 1   75.0             1593            1            41  Intermediate Level
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments
# 1           1 hour  2017-04-12T19:06:34Z  Musical Instruments

# %%
data.published_timestamp = pd.to_datetime(data.published_timestamp)
data.published_timestamp.dtype
# Out:
# datetime64[ns, UTC]

# %%
data['year']=data['published_timestamp'].dt.year

# %%
data
# Out:
#       course_id                                       course_title  is_paid  \
# 0        288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1       1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2       1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3       1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4       1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
# ...         ...                                                ...      ...
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
# ...

# %%
data[data.year==2015][['course_title','year']]
# Out:
#                                            course_title  year
# 10    1 - Concepts of Statistics For Beginners Step ...  2015
# 16          10 Numbers Every Business Owner Should Know  2015
# 19    101 Blues riffs - learn how the harmonica supe...  2015
# 23    16 Guitar Chords to Jam With - (Beginner - Int...  2015
# 26        2 Easy Steps To Investment And Avoiding Traps  2015
# ...                                                 ...   ...
# 3675                         Your First Course on Piano  2015
# 3676  Your First Successful Forex Trades - With Case...  2015
# 3677  Your Own Site in 45 Min: The Complete Wordpres...  2015
# 3678    Your Second Course on Piano: Two Handed Playing  2015
# 3679  Zend Framework 2: Learn the PHP framework ZF2 ...  2015
#
# [1014 rows x 2 columns]

# %%
data.head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
#
#    price  num_subscribers  num_reviews  num_lectures               level  \
# 0   35.0             3137           18            68          All Levels
# 1   75.0             1593            1            41  Intermediate Level
#
#   content_duration       published_timestamp              subject  year
# 0        1.5 hours 2014-09-18 05:07:05+00:00  Musical Instruments  2014
# 1           1 hour 2017-04-12 19:06:34+00:00  Musical Instruments  2017

# %%
data.groupby('level')[['num_subscribers']].max()
# Out:
#                     num_subscribers
# level
# All Levels                   268923
# Beginner Level               161029
# Expert Level                   5172
# Intermediate Level            29167

# %%
data.groupby('level')[['num_subscribers']].min()
# Out:
#                     num_subscribers
# level
# All Levels                        0
# Beginner Level                    0
# Expert Level                      1
# Intermediate Level                0
